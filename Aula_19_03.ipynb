# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiocelenza/Aulas_Python_Sergio/blob/main/Aula_19_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "Saulo"
cidade = input("Digite a cidade: ")

print(cidade)
print(nome)
# Out:
# Digite a cidade: São Carlos
# São Carlos
# Saulo

# %%
a = 1
b = 2
c = a + b
print(c)
# Out:
# 3

# %%
numero1 = 12
numero2 = 10
soma = numero1 + numero2
media = soma/2
print(media)
# Out:
# 401220020938255.0

# %%
numero1 = int(input("n1:"))
numero2 = int(input("n2:"))
soma = numero1 + numero2
media = soma/2
print(media)
# Out:
# n1:12
# n2:10
# 11.0

# %%
nome = input("digite seu nome:")
idade = int(input("digite sua idade:"))
salario = float(input("digitr seu salario:"))
print(f"Meu nome é {nome}, tenho {idade} anos e ganho {salario}")
