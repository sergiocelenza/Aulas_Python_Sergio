# %% [markdown]
# <a href="https://colab.research.google.com/github/sergiocelenza/Aulas_Python_Sergio/blob/main/aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 04: Estruturas de Decisão - Resolução e Lista de Exercícios
#
# Nesta aula, não vamos aprender comandos novos! Vamos treinar o que aprendemos sobre `if`, `elif`, `else`, e os operadores lógicos `and`, `or`, `not` com bastante prática.

# %% [markdown]
# ## Como resolver um problema de programação?
#
# 1.  **Entenda o problema:** Leia com atenção o que está sendo pedido.
# 2.  **Identifique as Entradas e Saídas:** O que eu recebo do usuário? O que eu devo mostrar na tela?
# 3.  **Esboce o Passo a Passo (Algoritmo):** "Primeiro, peço o valor X. Depois verifico se X é maior que 10. Se sim, faço isso."
# 4.  **Codifique:** Transforme seu passo a passo em código Python.
# 5.  **Teste:** Execute com os valores de exemplo e veja se funciona.

# %% [markdown]
# ## Exemplo Resolvido 1: Ano Bissexto
#
# **O problema:** Crie um programa que peça um ano (ex: 2024) e informe se ele é Bissexto ou não.
#
# *Regra do Ano Bissexto:*
# Ele precisa ser múltiplo de 4 (`ano % 4 == 0`).
# Mas se for fim de século (múltiplo de 100), ele **não** é bissexto, a menos que ele também seja múltiplo de 400.

# %%
# Solução do Professor
ano = int(input("Digite o ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"O ano {ano} É bissexto!")
else:
    print(f"O ano {ano} NÃO é bissexto.")
# Out:
# O ano 2026 NÃO é bissexto.

# %% [markdown]
# ## Exemplo Resolvido 2: Calculadora Simples
#
# **O problema:** Peça dois números e um operador matemático (`+`, `-`, `*` ou `/`) ao usuário. Imprima o resultado da operação.

# %%
num1 = float(input("Digite o primeiro número: "))
op = input("Digite a operação (+, -, *, /): ")
num2 = float(input("Digite o segundo número: "))

if op == "+":
    print(f"Resultado: {num1 + num2}")
elif op == "-":
    print(f"Resultado: {num1 - num2}")
elif op == "*":
    print(f"Resultado: {num1 * num2}")
elif op == "/":
    # Cuidados extras em programação: não se divide por zero!
    if num2 == 0:
        print("Erro: Divisão por zero.")
    else:
        print(f"Resultado: {num1 / num2}")
else:
    print("Operador inválido!")
# Out:
# Resultado: 3.0

# %% [markdown]
# ---
#
# ## Lista de Exercícios
#
# Agora é a sua vez. Resolva os exercícios abaixo nas células vazias.
#
# ### Desafio 1: Vogal ou Consoante
# Faça um programa que verifique se uma letra digitada é vogal ou consoante. Lembre-se, vogais são `a`, `e`, `i`, `o`, `u`.

# %%
letra = input("Digite uma letra: ").lower()

vogais = ('a', 'e', 'i', 'o', 'u')

if letra in vogais:
    print(f"A letra '{letra}' é uma vogal.")
else:
    print(f"A letra '{letra}' é uma consoante.")

# %% [markdown]
# ### Desafio 2: Aumento de Salário
# Faça um programa que calcule o aumento de salário de um funcionário.
# - Para salários maiores que R$ 1500,00, aumento de 10%.
# - Para salários menores ou iguais a R$ 1500,00, aumento de 15%.
# Multiplicar um valor por 1.10 é dar 10% de aumento.

# %%
salario = float(input("Qual o salário atual? "))

if salario > 1500.00:
    novo_salario = salario * 1.10
    print(f"Seu novo salário com 10% de aumento é: R$ {novo_salario:.2f}")
else:
    novo_salario = salario * 1.15
    print(f"Seu novo salário com 15% de aumento é: R$ {novo_salario:.2f}")

# %% [markdown]
# ### Desafio 3: Triângulos
# Peça os 3 lados de um triângulo. O programa deverá informar se os valores formam um triângulo. Caso formem, diga o tipo do triângulo:
# - Equilátero: 3 lados iguais;
# - Isósceles: 2 lados iguais;
# - Escaleno: 3 lados diferentes.
# *Dica: Para formar um triângulo, a soma de quaisquer dois lados precisa ser maior que o terceiro lado.*

# %%
a = 3
b = 5
c = 4
if (a + b > c and a + c > b and b + c > a):
  if (a == b and b == c):
    print("equilatero")
  elif (a != b and a!= c and b != c):
    print("escaleno")
  else:
    print("isosceles")
else:
  print("nao forma um triangulo")
# Out:
# escaleno

# %% [markdown]
# ### Exercício 1: Verificador de Número Positivo
# Crie um programa em C que peça ao usuário para digitar um número inteiro. Se o número for maior que zero, imprima "Número Positivo". Caso contrário, imprima "Número Não Positivo".

# %%
numero = int(input("Digite um numero inteiro"))
if (numero > 0):
  print("Numero positivo")
elif (numero < 0):
  print ("Numero negativo")
# Out:
# Digite um numero inteiro6
# Numero positivo

# %% [markdown]
# ### Exercício 2: Par ou Ímpar
# Escreva um programa em C que leia um número inteiro e determine se ele é par ou ímpar. Use o operador de módulo (`%`).

# %%
numero = int(input("Digite um numero: "))

if numero % 2 == 0:
    print(f"O número {numero} é PAR.")
else:
    print(f"O número {numero} é ÍMPAR.")

# %% [markdown]
# ### Exercício 3: Maior de Dois Números
# Faça um programa em C que leia dois números inteiros e imprima o maior entre eles. Use uma estrutura `if-else`.

# %%
numero1 = int(input("Digite um numero"))
numero2 = int(input("Digite um numero"))

if numero1 > numero2:
  print(f"O numero {numero1} é MAIOR que {numero2}")
elif numero1 < numero2:
  print(f"O numero {numero1} é MENOR que o {numero2}")
else:
  print(f"Os numeros {numero1} e {numero2} são IGUAIS.")
# Out:
# Digite um numero7
# Digite um numero5
# O numero 7 é MAIOR que 5

# %% [markdown]
# ### Exercício 4: Faixa Etária
# Desenvolva um programa em C que peça a idade de uma pessoa e informe se ela é `Criança` (0-12 anos), `Adolescente` (13-17 anos), `Adulto` (18-59 anos) ou `Idoso` (60 anos ou mais). Use `if-else if-else`.

# %%
idade = int(input("Digite sua idade: "))

if idade >= 0 and idade <= 12:
  print(f"Ela é uma criança")
elif idade >= 13 and idade <= 17:
  print (f"Ela é um(a) adolescente")
elif idade >= 18 and idade <= 59:
  print (f"Ela é um adulto")
else:
  print(f"Ela é um(a) idoso(a)")
# Out:
# Digite sua idade: 14
# Ela é um(a) adolescente

# %% [markdown]
# ### Exercício 5: Média e Situação do Aluno
# Crie um programa em C que leia três notas de um aluno (0 a 100) e calcule a média. Se a média for maior ou igual a 70, imprima "Aprovado". Se a média for entre 50 e 69 (inclusive), imprima "Recuperação". Caso contrário (abaixo de 50), imprima "Reprovado". Use operadores lógicos `&&`.

# %%
nota1 = float(input("Digite a primeira nota (0-100): "))
nota2 = float(input("Digite a segunda nota (0-100): "))
nota3 = float(input("Digite a terceira nota (0-100): "))

media = (nota1 + nota2 + nota3) / 3

print(f"Média: {media:.2f}")

if media >= 70:
    print("Situação: Aprovado")
elif media >= 50 and media <= 69:
    print("Situação: Recuperação")
else:
    print("Situação: Reprovado")

# %% [markdown]
# ### Exercício 6: Tipo de Triângulo
# Escreva um programa em C que leia os comprimentos dos três lados de um triângulo. Primeiro, verifique se os lados podem formar um triângulo (a soma de dois lados é sempre maior que o terceiro). Se sim, classifique o triângulo como `Equilátero` (todos os lados iguais), `Isósceles` (dois lados iguais) ou `Escaleno` (todos os lados diferentes). Use `&&` e `||`.

# %%
a = 2
b = 9
c = 9

# 1. Verifica se os lados formam um triângulo
if (a + b > c and a + c > b and b + c > a):
    # 2. Se sim, classifica o tipo
    if (a == b and b == c):
        print("equilatero")
    elif (a != b and a != c and b != c):
        print("escaleno")
    else:
        print("isosceles")
else:
    # 3. Se não passar na regra matemática
    print("nao forma um triangulo")
# Out:
# isosceles

# %% [markdown]
# ### Exercício 7: Login Simples
# Desenvolva um programa em C que simule um login. Peça ao usuário um `username` e uma `password`. Considere `admin` e `12345` como credenciais válidas. Se ambos estiverem corretos, imprima "Login bem-sucedido!". Caso contrário, imprima "Credenciais inválidas.". Use `strcmp` para comparar strings e `&&`.

# %%
username = input("Digite o username: ")
password = input("Digite a password: ")

if username == "admin" and password == "12345":
    print("Login bem-sucedido")
else:
    print("Senha ou login erradas")
# Out:
# Digite o username: admin
# Digite a password: 12345
# Login bem-sucedido

# %% [markdown]
# ### Exercício 8: Calculadora com Validação
# Crie uma calculadora simples em C. Peça dois números e um operador (`+`, `-`, `*`, `/`). Valide o operador: se for inválido, imprima uma mensagem de erro. Para a divisão, se o segundo número for zero, imprima "Erro: Divisão por zero.". Em outros casos, execute a operação e imprima o resultado. Use `if-else if-else` e `&&`.

# %%
num1 = float(input("Digite o primeiro número: "))
op = input("Digite o operador (+, -, *, /): ")
num2 = float(input("Digite o segundo número: "))

if op == "+":
    print(f"Resultado: {num1 + num2}")
elif op == "-":
    print(f"Resultado: {num1 - num2}")
elif op == "*":
    print(f"Resultado: {num1 * num2}")
elif op == "/":
    if num2 != 0:
        print(f"Resultado: {num1 / num2}")
    else:
        print("Erro")
else:
    print("Erro")
# Out:
# Digite o primeiro número: 5
# Digite o operador (+, -, *, /): +
# Digite o segundo número: 4
# Resultado: 9.0

# %% [markdown]
# ### Exercício 9: Ano Bissexto
# Faça um programa em C que determine se um ano digitado pelo usuário é bissexto. As regras são: um ano é bissexto se for divisível por 4, exceto se for divisível por 100 e não por 400. Exemplo: 2000 é bissexto, 1900 não é, 2024 é. Use `&&`, `||` e `!` (opcionalmente) de forma combinada.

# %%
ano = int(input("Digite o ano: "))

if (ano % 4 == 0 and ano % 100 != 0) or (ano % 400 == 0):
    print(f"{ano} é bissexto.")
else:
    print(f"{ano} não é bissexto.")

# %% [markdown]
# ### Exercício 10: Validação de Entrada Complexa
# Crie um programa em C que peça ao usuário para inserir um número `X` entre 1 e 100, uma string `S` que não seja vazia e um caractere `C` que seja uma vogal (`a`, `e`, `i`, `o`, `u`). O programa deve validar **todas** as entradas. Se todas as condições forem atendidas, imprima "Entradas Válidas!". Caso contrário, identifique qual condição falhou (pode ser mais de uma) e imprima mensagens de erro específicas para cada falha. Use uma combinação complexa de `if`, `else if`, `&&`, `||` e `!`.

# %%
"#professor essa nao consegui resolver nao,pedi pro chat me explicar melhor mais fiquei perdido ainda. nao copiei do chat pois pensei que vc poderia ficar bravo comigo."

# %%
primeira = 5>3 and 6<4 and 10>2 #[] and [] and []
print(primeira)
segunda = 5>2 or 6<4 or 4>2 # [] or [] or []
print(segunda)
conclusao = primeira or segunda
print(conclusao)
# Out:
# False
# True
# True

# %%
renda = 3000.0
idade = 33
tempo = 5
score = 750
dividas = 'n'
valor = 10000.0
limite = renda * 12 * 0.3 # 18000

criterio_1 = renda > 3000.0 and (idade > 25 or tempo > 5)
print(criterio_1)
criterio_2 = score > 700 and dividas == 'n'
print(criterio_2)
criterio_3 = valor < limite # [1]
print(criterio_3)

aprovado = (criterio_1 or criterio_2) and criterio_3
print(aprovado)
# Out:
# False
# True
# True
# True
